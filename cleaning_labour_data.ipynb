# %%
import pandas as pd

df1 = pd.read_csv('labour_force_province_raw.csv', skiprows=8, header=0)
print(df1.shape)
print(df1.head(3))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_37160\1507404370.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('labour_force_province_raw.csv', skiprows=8, header=0)
# (5430556, 19)
#    1976-01  Canada  2021A000011124  Population  Total - Gender  \
# 0  1976-01  Canada  2021A000011124  Population  Total - Gender
# 1  1976-01  Canada  2021A000011124  Population  Total - Gender
# 2  1976-01  Canada  2021A000011124  Population  Total - Gender
#
#       15 to 19 years  Estimate           Unadjusted  Persons in thousands  \
# 0     20 to 24 years  Estimate  Seasonally adjusted  Persons in thousands
# 1     20 to 24 years  Estimate           Unadjusted  Persons in thousands
# 2  25 years and over  Estimate  Seasonally adjusted  Persons in thousands
#
#    428  thousands  3  v2064942  1.1.1.3.1.2   2330.0 Unnamed: 15  Unnamed: 16  \
# 0  428  thousands  3  v2062890  1.1.1.4.1.1   2179.8         NaN          NaN
# ...

# %%
print(df1.columns.tolist())
print(df1.shape)
# Out:
# ['1976-01', 'Canada', '2021A000011124', 'Population', 'Total - Gender', '15 to 19 years', 'Estimate', 'Unadjusted', 'Persons in thousands', '428', 'thousands', '3', 'v2064942', '1.1.1.3.1.2', '2330.0', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', '1']
# (5430556, 19)

# %%
df1 = pd.read_csv('labour_force_province_raw.csv', header=0)
print(df1.columns.tolist())
print(df1.head(3))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_37160\4290579646.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('labour_force_province_raw.csv', header=0)
# ['REF_DATE', 'GEO', 'DGUID', 'Labour force characteristics', 'Gender', 'Age group', 'Statistics', 'Data type', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
#   REF_DATE     GEO           DGUID Labour force characteristics  \
# 0  1976-01  Canada  2021A000011124                   Population
# 1  1976-01  Canada  2021A000011124                   Population
# 2  1976-01  Canada  2021A000011124                   Population
#
#            Gender          Age group Statistics            Data type  \
# 0  Total - Gender  15 years and over   Estimate  Seasonally adjusted
# 1  Total - Gender  15 years and over   Estimate           Unadjusted
# ...

# %%
# Filter to what we need
df1_clean = df1[
    (df1['REF_DATE'] >= '2019-01') &
    (df1['GEO'] != 'Canada') &
    (df1['Gender'] == 'Total - Gender') &
    (df1['Age group'] == '15 years and over') &
    (df1['Data type'] == 'Seasonally adjusted') &
    (df1['Labour force characteristics'].isin([
        'Employment', 
        'Unemployment rate',
        'Participation rate'
    ]))
][['REF_DATE', 'GEO', 'Labour force characteristics', 'VALUE']]

print(df1_clean.shape)
print(df1_clean.head(10))
print(df1_clean['GEO'].unique())
# Out:
# (10560, 4)
#         REF_DATE                        GEO Labour force characteristics  \
# 4640535  2019-01  Newfoundland and Labrador                   Employment
# 4640538  2019-01  Newfoundland and Labrador                   Employment
# 4640539  2019-01  Newfoundland and Labrador                   Employment
# 4640540  2019-01  Newfoundland and Labrador                   Employment
# 4640904  2019-01  Newfoundland and Labrador            Unemployment rate
# 4640906  2019-01  Newfoundland and Labrador            Unemployment rate
# 4640907  2019-01  Newfoundland and Labrador            Unemployment rate
# 4640908  2019-01  Newfoundland and Labrador            Unemployment rate
# 4641000  2019-01  Newfoundland and Labrador           Participation rate
# 4641002  2019-01  Newfoundland and Labrador           Participation rate
#
#          VALUE
# 4640535  235.5
# 4640538    3.3
# 4640539    2.1
# 4640540    4.1
# 4640904   11.7
# 4640906    0.8
# 4640907    0.7
# 4640908    1.1
# ...

# %%
# Check what's causing duplicates
print(df1[
    (df1['REF_DATE'] == '2019-01') &
    (df1['GEO'] == 'Newfoundland and Labrador') &
    (df1['Gender'] == 'Total - Gender') &
    (df1['Age group'] == '15 years and over') &
    (df1['Data type'] == 'Seasonally adjusted') &
    (df1['Labour force characteristics'] == 'Employment')
][['REF_DATE', 'GEO', 'Labour force characteristics', 'Statistics', 'VALUE']])
# Out:
#         REF_DATE                        GEO Labour force characteristics  \
# 4640535  2019-01  Newfoundland and Labrador                   Employment
# 4640538  2019-01  Newfoundland and Labrador                   Employment
# 4640539  2019-01  Newfoundland and Labrador                   Employment
# 4640540  2019-01  Newfoundland and Labrador                   Employment
#
#                                       Statistics  VALUE
# 4640535                                 Estimate  235.5
# 4640538               Standard error of estimate    3.3
# 4640539  Standard error of month-to-month change    2.1
# 4640540  Standard error of year-over-year change    4.1

# %%
df1_clean = df1[
    (df1['REF_DATE'] >= '2019-01') &
    (df1['GEO'] != 'Canada') &
    (df1['Gender'] == 'Total - Gender') &
    (df1['Age group'] == '15 years and over') &
    (df1['Data type'] == 'Seasonally adjusted') &
    (df1['Statistics'] == 'Estimate') &
    (df1['Labour force characteristics'].isin([
        'Employment', 
        'Unemployment rate',
        'Participation rate'
    ]))
][['REF_DATE', 'GEO', 'Labour force characteristics', 'VALUE']]

print(df1_clean.shape)
print(df1_clean.head(10))
# Out:
# (2640, 4)
#         REF_DATE                        GEO Labour force characteristics  \
# 4640535  2019-01  Newfoundland and Labrador                   Employment
# 4640904  2019-01  Newfoundland and Labrador            Unemployment rate
# 4641000  2019-01  Newfoundland and Labrador           Participation rate
# 4641330  2019-01       Prince Edward Island                   Employment
# 4641699  2019-01       Prince Edward Island            Unemployment rate
# 4641795  2019-01       Prince Edward Island           Participation rate
# 4642125  2019-01                Nova Scotia                   Employment
# 4642494  2019-01                Nova Scotia            Unemployment rate
# 4642590  2019-01                Nova Scotia           Participation rate
# 4642920  2019-01              New Brunswick                   Employment
#
#          VALUE
# 4640535  235.5
# 4640904   11.7
# 4641000   59.4
# 4641330   76.0
# 4641699   10.1
# 4641795   66.5
# 4642125  459.9
# 4642494    7.4
# ...

# %%
df1_clean.to_csv('labour_force_clean.csv', index=False)
print("Saved successfully")
print(f"Rows: {df1_clean.shape[0]}")
print(f"Provinces: {df1_clean['GEO'].nunique()}")
print(f"Date range: {df1_clean['REF_DATE'].min()} to {df1_clean['REF_DATE'].max()}")
# Out:
# Saved successfully
# Rows: 2640
# Provinces: 10
# Date range: 2019-01 to 2026-04

# %%
df2 = pd.read_csv('wages_province_raw.csv', header=0, skiprows=8, encoding='latin-1')
print(df2.columns.tolist()[:10])
print(df2.shape)
print(df2.head(3))
# Out:
# ['Geography 3', 'Canada', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9']
# (42, 89)
#     Geography 3                              Canada Unnamed: 2 Unnamed: 3  \
# 0       Wages 4            Average hourly wage rate        NaN        NaN
# 1  Type of work  Both full- and part-time employees        NaN        NaN
# 2    Gender 5 6                      Total - Gender        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2        NaN        NaN        NaN        NaN        NaN        NaN  ...
#
#   Unnamed: 79 Unnamed: 80 Unnamed: 81 Unnamed: 82 Unnamed: 83 Unnamed: 84  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# Check what characteristics are available in our clean dataset
print(df1['Labour force characteristics'].unique())
# Out:
# ['Population' 'Labour force' 'Employment' 'Full-time employment'
#  'Part-time employment' 'Unemployment' 'Unemployment rate'
#  'Participation rate' 'Employment rate']

# %%
df1_clean = df1[
    (df1['REF_DATE'] >= '2019-01') &
    (df1['GEO'] != 'Canada') &
    (df1['Gender'] == 'Total - Gender') &
    (df1['Age group'] == '15 years and over') &
    (df1['Data type'] == 'Seasonally adjusted') &
    (df1['Statistics'] == 'Estimate') &
    (df1['Labour force characteristics'].isin([
        'Employment',
        'Full-time employment',
        'Part-time employment',
        'Unemployment rate',
        'Participation rate',
        'Employment rate'
    ]))
][['REF_DATE', 'GEO', 'Labour force characteristics', 'VALUE']]

print(df1_clean.shape)
print(df1_clean['Labour force characteristics'].unique())
print(f"Date range: {df1_clean['REF_DATE'].min()} to {df1_clean['REF_DATE'].max()}")
# Out:
# (5280, 4)
# ['Employment' 'Full-time employment' 'Part-time employment'
#  'Unemployment rate' 'Participation rate' 'Employment rate']
# Date range: 2019-01 to 2026-04

# %%
df1_clean.to_csv('labour_force_clean.csv', index=False)
print("Saved successfully")
print(f"Rows: {df1_clean.shape[0]}")
print(f"Provinces: {df1_clean['GEO'].nunique()}")
# Out:
# Saved successfully
# Rows: 5280
# Provinces: 10
